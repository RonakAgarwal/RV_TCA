# %% [markdown]
# # RV Pre Super Day Case

# %%
import pandas as pd
import numpy as np
import plotly as plt

# %%
df = pd.read_excel(r'data/candidate_set.xlsx')
df = df.dropna()

# %%
df.head()
# Out:
#                                 User ID  applications  \
# 0  00007820-89cb-4c1d-9940-eb270d605a35             1
# 1  00012b55-514c-421e-9c76-3300abbc1134             1
# 2  000157c1-b6a3-4c86-82c7-9ec1bda3799a             1
# 3  00020400-efab-4b10-8812-2a0aaf774841             1
# 4  0002f737-0cda-48fb-91ed-533f3d0eab05             1
#
#                      Reason  Loan_Amount  FICO_score Fico_Score_group  \
# 0  cover_an_unexpected_cost       100000         669             fair
# 1   credit_card_refinancing        70000         594             fair
# 2          home_improvement        10000         596             fair
# 3          home_improvement       100000         642             fair
# 4            major_purchase        30000         642             fair
#
#   Employment_Status       Employment_Sector  Monthly_Gross_Income  \
# 0         full_time  consumer_discretionary                  5024
# 1         full_time  information_technology                  5764
# ...

# %% [markdown]
# ## Question 1

# %%
df_approved = df[df["Approved"] == 1]
df_approved.head()
# Out:
#                                  User ID  applications  \
# 6   0004091e-ef33-4feb-9fc2-7da41b1edadd             1
# 41  00150abb-36ce-4e46-aa86-af7d75654a05             1
# 42  001524af-8e8d-41df-bb88-67fd1ac66a9e             1
# 45  00174af3-6120-43ba-8476-a5333c6d8b26             1
# 81  002e92f8-f2ef-4a30-8a88-acb58a34d2f6             1
#
#                      Reason  Loan_Amount  FICO_score Fico_Score_group  \
# 6                     other        80000         691             good
# 41  credit_card_refinancing        90000         779        very_good
# 42  credit_card_refinancing       100000         785        very_good
# 45                    other        30000         708             good
# 81         home_improvement       100000         562             poor
#
#    Employment_Status       Employment_Sector  Monthly_Gross_Income  \
# 6          full_time  communication_services                  5103
# 41         full_time             health_care                 10710
# ...

# %%
df_denied = df[df["Approved"] == 0]
df_denied.head()
# Out:
#                                 User ID  applications  \
# 0  00007820-89cb-4c1d-9940-eb270d605a35             1
# 1  00012b55-514c-421e-9c76-3300abbc1134             1
# 2  000157c1-b6a3-4c86-82c7-9ec1bda3799a             1
# 3  00020400-efab-4b10-8812-2a0aaf774841             1
# 4  0002f737-0cda-48fb-91ed-533f3d0eab05             1
#
#                      Reason  Loan_Amount  FICO_score Fico_Score_group  \
# 0  cover_an_unexpected_cost       100000         669             fair
# 1   credit_card_refinancing        70000         594             fair
# 2          home_improvement        10000         596             fair
# 3          home_improvement       100000         642             fair
# 4            major_purchase        30000         642             fair
#
#   Employment_Status       Employment_Sector  Monthly_Gross_Income  \
# 0         full_time  consumer_discretionary                  5024
# 1         full_time  information_technology                  5764
# ...

# %%
df.groupby(['Approved']).mean().head()
# Out:
#           applications   Loan_Amount  FICO_score  Monthly_Gross_Income  \
# Approved
# 0                  1.0  45659.282383  620.929431           5880.106594
# 1                  1.0  42506.588855  697.000000           7414.705384
#
#           Monthly_Housing_Payment  Ever_Bankrupt_or_Foreclose      bounty
# Approved
# 0                     1666.758295                    0.017476    0.000000
# 1                     1616.703972                    0.006965  242.319277

# %%
df.groupby(['Employment_Status']).mean().head()
# Out:
#                    applications   Loan_Amount  FICO_score  \
# Employment_Status
# full_time                   1.0  45207.437703  629.548851
# part_time                   1.0  45722.866854  629.634201
#
#                    Monthly_Gross_Income  Monthly_Housing_Payment  \
# Employment_Status
# full_time                   6687.488142              1718.427472
# part_time                   3214.581224              1403.867557
#
#                    Ever_Bankrupt_or_Foreclose  Approved     bounty
# Employment_Status
# full_time                            0.011603  0.120712  29.543049
# part_time                            0.037271  0.081224  18.372011

# %%
df.groupby(['Employment_Sector']).mean().head()
# Out:
#                         applications   Loan_Amount  FICO_score  \
# Employment_Sector
# communication_services           1.0  45733.283246  620.675131
# consumer_discretionary           1.0  46509.374007  616.076899
# consumer_staples                 1.0  45942.723423  623.724983
# energy                           1.0  44962.955927  626.871771
# financials                       1.0  45368.171021  638.198121
#
#                         Monthly_Gross_Income  Monthly_Housing_Payment  \
# Employment_Sector
# communication_services           5553.552216              1663.380165
# consumer_discretionary           4850.919924              1611.133778
# consumer_staples                 5618.986405              1649.118008
# energy                           5939.958207              1665.036474
# financials                       6702.077305              1676.230296
#
#                         Ever_Bankrupt_or_Foreclose  Approved     bounty
# Employment_Sector
# ...

# %%
df.groupby(['Reason']).mean().head()
# Out:
#                           applications   Loan_Amount  FICO_score  \
# Reason
# cover_an_unexpected_cost           1.0  45880.327776  629.645991
# credit_card_refinancing            1.0  44823.954633  629.089799
# debt_conslidation                  1.0  44878.133840  628.880459
# home_improvement                   1.0  45596.468157  630.358726
# major_purchase                     1.0  45400.093433  630.403764
#
#                           Monthly_Gross_Income  Monthly_Housing_Payment  \
# Reason
# cover_an_unexpected_cost           6190.279577              1715.815057
# credit_card_refinancing            6010.523400              1650.208388
# debt_conslidation                  6022.453210              1621.144147
# home_improvement                   6038.368213              1666.429833
# major_purchase                     6032.288841              1672.225574
#
#                           Ever_Bankrupt_or_Foreclose  Approved     bounty
# Reason
# ...

# %%
df.groupby(['Fico_Score_group']).mean().head()
# Out:
#                   applications   Loan_Amount  FICO_score  \
# Fico_Score_group
# excellent                  1.0  45279.261778  824.663429
# fair                       1.0  45368.524725  625.720321
# good                       1.0  45201.915709  702.809655
# poor                       1.0  45253.342849  522.785081
# very_good                  1.0  45643.244370  767.228315
#
#                   Monthly_Gross_Income  Monthly_Housing_Payment  \
# Fico_Score_group
# excellent                  9916.161729              1679.579407
# fair                       5771.681043              1659.926383
# good                       6716.970881              1660.077701
# poor                       5108.630221              1657.814002
# very_good                  8044.192452              1684.836113
#
#                   Ever_Bankrupt_or_Foreclose  Approved      bounty
# Fico_Score_group
# excellent                           0.009228  0.464789  120.179699
# ...

# %% [markdown]
# ## Question 2

# %%
df.groupby(['Lender']).mean().head()
# Out:
#         applications   Loan_Amount  FICO_score  Monthly_Gross_Income  \
# Lender
# A                1.0  45271.959178  630.196657           6036.500897
# B                1.0  45311.764706  630.550706           6211.776353
# C                1.0  45396.315338  625.326478           5836.318195
#
#         Monthly_Housing_Payment  Ever_Bankrupt_or_Foreclose  Approved  \
# Lender
# A                   1685.305922                    0.018876  0.109856
# B                   1746.650118                    0.004667  0.075804
# C                   1411.671094                    0.027421  0.196301
#
#            bounty
# Lender
# A       27.463995
# B       26.531373
# C       29.445159

# %%
df_approved.groupby(['Lender']).mean().head()
# Out:
#         applications   Loan_Amount  FICO_score  Monthly_Gross_Income  \
# Lender
# A                1.0  42602.659037  696.981656           7571.386570
# B                1.0  42141.748577  731.498189           8114.566994
# C                1.0  42555.474718  672.781739           6583.918880
#
#         Monthly_Housing_Payment  Ever_Bankrupt_or_Foreclose  Approved  bounty
# Lender
# A                   1708.551834                    0.005554       1.0   250.0
# B                   1699.520952                    0.000000       1.0   350.0
# C                   1359.939614                    0.014915       1.0   150.0

# %%
df_approved.groupby(['Lender', 'Employment_Status']).sum().head(6)
# Out:
#                           applications  Loan_Amount  FICO_score  \
# Lender Employment_Status
# A      full_time                  5238    228815000     3639561
#        part_time                   704     24330000      501904
# B      full_time                  1757     74005000     1284578
#        part_time                   176      7455000      129408
# C      full_time                  2243     95010000     1503701
#        part_time                   506     21975000      345776
#
#                           Monthly_Gross_Income  Monthly_Housing_Payment  \
# Lender Employment_Status
# A      full_time                      42670435                  8705626
#        part_time                       2318744                  1446589
# B      full_time                      15101421                  3100297
#        part_time                        584037                   184877
# C      full_time                      16496983                  3184799
# ...

# %%
df_approved.groupby(['Lender', 'Fico_Score_group']).sum().head(15)
# Out:
#                          applications  Loan_Amount  FICO_score  \
# Lender Fico_Score_group
# A      excellent                  513     22255000      422956
#        fair                      1269     52100000      796898
#        good                      2837    120870000     2000747
#        poor                       409     16940000      219375
#        very_good                  914     40980000      701489
# B      excellent                  263     11445000      216635
#        fair                       153      6590000       98957
#        good                       999     41585000      701110
#        very_good                  518     21840000      397284
# C      excellent                  181      7710000      149130
#        fair                       861     33930000      541183
#        good                      1025     45295000      720837
#        poor                       367     15925000      196414
# ...

# %% [markdown]
# ## Question 3

# %%
df.groupby(['Lender', 'Fico_Score_group']).mean().head(15)
# Out:
#                          applications   Loan_Amount  FICO_score  \
# Lender Fico_Score_group
# A      excellent                  1.0  44965.724079  824.874036
#        fair                       1.0  45472.639401  625.616432
#        good                       1.0  45223.004695  703.716851
#        poor                       1.0  45033.196641  522.540845
#        very_good                  1.0  45638.214565  769.601410
# B      excellent                  1.0  47200.674536  824.374368
#        fair                       1.0  45369.909012  625.931218
#        good                       1.0  44903.747995  700.795392
#        poor                       1.0  45392.608089  522.787029
#        very_good                  1.0  45652.305825  763.261529
# C      excellent                  1.0  42692.307692  824.414716
#        fair                       1.0  45004.513450  625.729735
#        good                       1.0  45693.766159  702.669635
# ...

# %%
df_approved.groupby(['Lender', 'Fico_Score_group', 'Ever_Bankrupt_or_Foreclose']).sum()
# Out:
#                                                     applications  Loan_Amount  \
# Lender Fico_Score_group Ever_Bankrupt_or_Foreclose
# A      excellent        0                                    510     22175000
#                         1                                      3        80000
#        fair             0                                   1265     51990000
#                         1                                      4       110000
#        good             0                                   2817    120205000
#                         1                                     20       665000
#        poor             0                                    408     16870000
#                         1                                      1        70000
#        very_good        0                                    909     40890000
#                         1                                      5        90000
# ...

# %%
df_set1 = df[(df["Lender"] != 'B') & (df['Monthly_Gross_Income'] > 8000) & (df['FICO_score'] > 740)]

# %%
df_set1.head()
# Out:
#                                  User ID  applications  \
# 10  00076e11-3b6f-41cd-a2b7-f4ffe8fe2fbf             1
# 34  001231ad-0aef-4d84-86e1-306dbcea9310             1
# 41  00150abb-36ce-4e46-aa86-af7d75654a05             1
# 42  001524af-8e8d-41df-bb88-67fd1ac66a9e             1
# 60  00227343-b9eb-469a-9b82-83b03d36ca00             1
#
#                      Reason  Loan_Amount  FICO_score Fico_Score_group  \
# 10         home_improvement        40000         793        very_good
# 34        debt_conslidation        10000         755        very_good
# 41  credit_card_refinancing        90000         779        very_good
# 42  credit_card_refinancing       100000         785        very_good
# 60         home_improvement        30000         762        very_good
#
#    Employment_Status       Employment_Sector  Monthly_Gross_Income  \
# 10         full_time  information_technology                 10292
# 34         full_time             real_estate                 12198
# ...

# %%
df_set1.groupby(['Fico_Score_group']).sum().head()
# Out:
#                   applications  Loan_Amount  FICO_score  Monthly_Gross_Income  \
# Fico_Score_group
# excellent                 1058     47000000      872650              12847651
# very_good                 1496     67595000     1152107              16779062
#
#                   Monthly_Housing_Payment  Ever_Bankrupt_or_Foreclose  \
# Fico_Score_group
# excellent                         1775538                           6
# very_good                         2482675                          20
#
#                   Approved  bounty
# Fico_Score_group
# excellent              507  114250
# very_good              592  134100

# %%
df_set1['bounty'].sum()
# Out:
# 248350

# %%
df.groupby(['Lender', 'Fico_Score_group']).mean().head(15)
# Out:
#                          applications   Loan_Amount  FICO_score  \
# Lender Fico_Score_group
# A      excellent                  1.0  44965.724079  824.874036
#        fair                       1.0  45472.639401  625.616432
#        good                       1.0  45223.004695  703.716851
#        poor                       1.0  45033.196641  522.540845
#        very_good                  1.0  45638.214565  769.601410
# B      excellent                  1.0  47200.674536  824.374368
#        fair                       1.0  45369.909012  625.931218
#        good                       1.0  44903.747995  700.795392
#        poor                       1.0  45392.608089  522.787029
#        very_good                  1.0  45652.305825  763.261529
# C      excellent                  1.0  42692.307692  824.414716
#        fair                       1.0  45004.513450  625.729735
#        good                       1.0  45693.766159  702.669635
# ...

# %% [markdown]
# Lender B has an approval rate of 0.443508 for excellent and 0.314320 for very good.

# %%
bex = 1058 * 0.443508 * 350
bvg = 1496 * 0.314320 * 350

# %%
bex + bvg
# Out:
# 328808.9644

# %%
btotal = (bex + bvg) - (114250 + 134100)
btotal
# Out:
# 80458.9644

# %%
df_set2 = df[(df["Lender"] != 'A') & (df['Ever_Bankrupt_or_Foreclose'] == 1) & (df['FICO_score'] > 740)]

# %%
df_set2.groupby(['Fico_Score_group']).sum().head()
# Out:
#                   applications  Loan_Amount  FICO_score  Monthly_Gross_Income  \
# Fico_Score_group
# excellent                    7       285000        5749                 71827
# very_good                   28      1240000       21355                181675
#
#                   Monthly_Housing_Payment  Ever_Bankrupt_or_Foreclose  \
# Fico_Score_group
# excellent                            9537                           7
# very_good                           36149                          28
#
#                   Approved  bounty
# Fico_Score_group
# excellent                1     150
# very_good                8    1200

# %%
df_set3 = df[(df["Lender"] != 'C') & (df['FICO_score'] < 660)]

# %%
df_set3.groupby(['Fico_Score_group']).sum().head()
# Out:
#                   applications  Loan_Amount  FICO_score  Monthly_Gross_Income  \
# Fico_Score_group
# fair                     24963   1132770000    15481796             144400101
# poor                     22533   1017310000    11776178             115519279
#
#                   Monthly_Housing_Payment  Ever_Bankrupt_or_Foreclose  \
# Fico_Score_group
# fair                             42626428                         334
# poor                             38367271                         323
#
#                   Approved  bounty
# Fico_Score_group
# fair                  1210  314800
# poor                   409  102250

# %%
cex = 24963 * 0.155443 * 150
cvg = 22533 * 0.089709 * 150

# %%
cex + cvg
# Out:
# 885260.4759

# %%
ctotal = (cex + cvg) - (314800 + 102250)
ctotal
# Out:
# 468210.47589999996

# %%
ctotal+btotal
# Out:
# 548669.4402999999
